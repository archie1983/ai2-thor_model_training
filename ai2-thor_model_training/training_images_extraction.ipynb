# %%
from training_data_extraction import NavigationTrainingDataExtractor
ntde = NavigationTrainingDataExtractor()
ntde.process_1_batch_of_habitats()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Highest habitat explored: 2
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# ...
# Loading test: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 11269.29it/s]
# Loading : train[3]
# ...

# %%
from model_training import HabitatNNTrainer
hnt = HabitatNNTrainer(architecture_id = 1, batch_size = 10)
hnt.do_epochs(5)
# Out:
# HabitatNeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=451584, out_features=1013, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=1013, out_features=512, bias=True)
#     (3): Sigmoid()
#     (4): Linear(in_features=512, out_features=512, bias=True)
#     (5): Sigmoid()
#     (6): Linear(in_features=512, out_features=4, bias=True)
#   )
# )
# Epoch 1
# -------------------------------
# loss: 1.352322  [    0/ 2367]
# loss: 1.131673  [  200/ 2367]
# loss: 1.020652  [  400/ 2367]
# loss: 0.965269  [  600/ 2367]
# loss: 0.795333  [  800/ 2367]
# loss: 1.146878  [ 1000/ 2367]
# loss: 1.413395  [ 1200/ 2367]
# loss: 0.976249  [ 1400/ 2367]
# loss: 0.852579  [ 1600/ 2367]
# loss: 1.151140  [ 1800/ 2367]
# loss: 1.116862  [ 2000/ 2367]
# loss: 1.375096  [ 2200/ 2367]
# Test Error:
#  Accuracy: 56.3%, Avg loss: 1.181997
#
# Epoch 2
# -------------------------------
# loss: 1.468384  [    0/ 2367]
# ...

# %%
from navigation_training_data_extractor import NavigationTrainingDataExtractor

ntde = NavigationTrainingDataExtractor("train_59")
#path = spp.bring_me_a_bottle_of_beer()

doors = ntde.find_all_doors()
path_and_plan = ntde.get_path_to_actual_object(doors[0], is_door=True)
path = path_and_plan[0]
plan = path_and_plan[1]
ntde.visualise_path(path)
ntde.navigate_to_door()


ntde.ae_load_proctor_scene("train_60")

doors = ntde.find_all_doors()
path_and_plan = ntde.get_path_to_actual_object(doors[0], is_door=True)
path = path_and_plan[0]
plan = path_and_plan[1]
ntde.visualise_path(path)
ntde.navigate_to_door()

ntde.rnc.controller.stop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from navigation_training_data_extractor import NavigationTrainingDataExtractor
#       3 ntde = NavigationTrainingDataExtractor("train_59")
#       4 #path = spp.bring_me_a_bottle_of_beer()
#
# ModuleNotFoundError: No module named 'navigation_training_data_extractor'

# %%
from navigation_training_data_extractor import NavigationTrainingDataExtractor
from ae_robot_simulation_control import RobotNavigationControl

spp = NavigationTrainingDataExtractor("train_58")
doors = spp.find_all_doors()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from navigation_training_data_extractor import NavigationTrainingDataExtractor
#       2 from ae_robot_simulation_control import RobotNavigationControl
# ----> 4 spp = NavigationTrainingDataExtractor("train_58")
#       5 doors = spp.find_all_doors()
#
# TypeError: NavigationTrainingDataExtractor.__init__() missing 1 required positional argument: 'data_store_dir'

# %%
spp.ae_load_proctor_scene("train_59")
# Out:
# Loading : train[59]
# ROOMS:[('Bedroom', [(4.877, 4.877), (4.877, 11.379), (9.754, 11.379), (9.754, 8.128), (11.379, 8.128), (11.379, 4.877)], <POINT (7.78 7.896)>), ('Bathroom', [(4.877, 1.626), (4.877, 4.877), (11.379, 4.877), (11.379, 1.626)], <POINT (8.128 3.252)>), ('Kitchen', [(0.0, 4.877), (0.0, 11.379), (4.877, 11.379), (4.877, 4.877)], <POINT (2.438 8.128)>), ('LivingRoom', [(3.251, 1.626), (3.251, 0.0), (1.626, 0.0), (1.626, 3.251), (0.0, 3.251), (0.0, 4.877), (4.877, 4.877), (4.877, 1.626)], <POINT (2.709 2.981)>)]

# %%
doors = spp.find_all_doors()
door_of_interest = doors[0]
print(door_of_interest)
path_and_plan = spp.get_path_to_actual_object(door_of_interest, is_door=True)
path = path_and_plan[0]
plan = path_and_plan[1]
spp.visualise_path(path)
# Out:
# {'name': 'door|4|5', 'position': {'x': 7.133347034454346, 'y': -0.0005983114242553711, 'z': 4.876949787139893}, 'rotation': {'x': -0.0, 'y': 180.0, 'z': 0.0}, 'visible': False, 'isInteractable': False, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': True, 'isOpen': True, 'openness': 1.0, 'pickupable': False, 'isPickedUp': False, 'moveable': False, 'mass': 0.0, 'salientMaterials': None, 'receptacleObjectIds': None, 'distance': 4.6810126304626465, 'objectType': 'Doorway', 'objectId': 'door|4|5', 'assetId': 'Doorway_8', 'parentReceptacles': ['Floor'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': 
# ...

# %%
spp.navigate_to_door()
# Out:
# ({'x': 14.25, 'y': 0.9009997844696045, 'z': 3.75}, {'x': 0.0, 'y': 225.0, 'z': 0.0})
# ({'x': 14.25, 'y': 0.9009997844696045, 'z': 3.75}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 14.25, 'y': 0.9009997844696045, 'z': 3.75}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# ({'x': 14.0, 'y': 0.9009997844696045, 'z': 4.0}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# ({'x': 13.75, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# ({'x': 13.75, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 13.5, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 13.25, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 13.0, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 12.75, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 12.5, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ...

# %%
door_of_interest = doors[3]
path_and_plan = spp.get_path_to_actual_object(door_of_interest, is_door=True)
path = path_and_plan[0]
plan = path_and_plan[1]

for element in path:
    print(element)
#print(path

spp.rnc.follow_planned_path(path)
# Out:
# ({'x': 14.25, 'y': 0.9009997844696045, 'z': 3.75}, {'x': 0.0, 'y': 225.0, 'z': 0.0})
# ({'x': 14.25, 'y': 0.9009997844696045, 'z': 3.75}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 14.25, 'y': 0.9009997844696045, 'z': 3.75}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# ({'x': 14.0, 'y': 0.9009997844696045, 'z': 4.0}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# ({'x': 13.75, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# ({'x': 13.75, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 13.5, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 13.25, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 13.0, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 12.75, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ({'x': 12.5, 'y': 0.9009997844696045, 'z': 4.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ...

# %%
doors_sorted = spp.get_all_doors_sorted_by_distance_from_current_pose()
#for (door in doors_sorted):
#    path = door[1]
#    rnc.navigate_to_pose()

path = doors_sorted[1][1]
#for pose in path:
#    print(rnc.get_agent_pos_and_rotation())
#    rnc.navigate_to_pose(pose)
spp.rnc.follow_planned_path(path)
# Out:
# navigating to:  ({'x': 17.0, 'y': 0.9009993672370911, 'z': 12.75}, {'x': 0.0, 'y': 315.0, 'z': 0.0})
# navigating to:  ({'x': 17.0, 'y': 0.9009993672370911, 'z': 12.75}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# navigating to:  ({'x': 17.0, 'y': 0.9009993672370911, 'z': 12.75}, {'x': 0.0, 'y': 225.0, 'z': 0.0})
# navigating to:  ({'x': 16.75, 'y': 0.9009993672370911, 'z': 12.5}, {'x': 0.0, 'y': 225.0, 'z': 0.0})
# navigating to:  ({'x': 16.5, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 225.0, 'z': 0.0})
# navigating to:  ({'x': 16.5, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# navigating to:  ({'x': 16.25, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# navigating to:  ({'x': 16.0, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# navigating to:  ({'x': 15.75, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 270.0, 'z': 0.0})
# ...

# %%
print(path)
# Out:
# [({'x': 4.25, 'y': 0.9009993672370911, 'z': 13.0}, {'x': 0.0, 'y': 135.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 13.0}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.75}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.5}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.0}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.75}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.5}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.25}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.0}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 10.75}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 10.5}, {'x': 0
# ...

# %%
#path = spp.get_path_to_actual_object(doors_sorted[0])
spp.visualise_path(path)
# Out:
# 0.0 14.5 0.0 14.5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 #path = spp.get_path_to_actual_object(doors_sorted[0])
# ----> 2 spp.visualise_path(path)
#
# File ~/robotics/Florence/yolo_semantic_navigation/navigation_training_data_extractor.py:243, in NavigationTrainingDataExtractor.visualise_path(self, path)
#     236 # another way how to plot the path
#     237 #x = [p[0]["x"] for p in path]
#     238 #z = [p[0]["z"] for p in path]
#     239 #ax.scatter(x, z, s=300, c='gray', zorder=1)
#     240
#     241 # setting up for the top-down picture of the habitat
#     242 print(str(x_min-grid_size) + " " + str(x_max+grid_size) + " " + str(z_min-grid_size) + " " + str(z_max+grid_size))
# --> 243 img = self.get_top_down_frame()
#     244 ex_mul = 7
# ...

# %%
#for i in range(10):
spp.rnc.return_to_prev_pose()
# Out:
# ((4.25, 0.9009993672370911, 13.0), (-0.0, 90.0, 0.0))
# navigating to:  ((4.25, 0.9009993672370911, 13.0), (-0.0, 90.0, 0.0))

# %%
ev = spp.rnc.controller.step(action="Done")
print("CV2IMG: ", str(len(ev.cv2img)))
ev.cv2img[0:10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 ev = rnc.controller.step(action="Done")
# ----> 2 print("CV2IMG: ", str(len(ev.cv2img)))
#       3 ev.cv2img[0:10]
#
# File ~/anaconda3/envs/ai2-thor/lib/python3.10/site-packages/ai2thor/server.py:707, in Event.cv2img(self)
#     705 @property
#     706 def cv2img(self):
# --> 707     return self.frame[..., ::-1]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
print(path)
# Out:
# [({'x': 4.25, 'y': 0.9009993672370911, 'z': 13.0}, {'x': 0.0, 'y': 135.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 13.0}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.75}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.5}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.25}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 12.0}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.75}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.5}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.25}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 11.0}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 10.75}, {'x': 0.0, 'y': 180.0, 'z': 0.0}), ({'x': 4.25, 'y': 0.9009993672370911, 'z': 10.5}, {'x': 0
# ...

# %%
path = doors_sorted[0][1]
#for pose in path:
#    print(rnc.get_agent_pos_and_rotation())
#    rnc.navigate_to_pose(pose)
spp.rnc.follow_planned_path(path)

# %%
print(doors_sorted[0])
# Out:
# (0, [])

# %%
print(doors[3])
# Out:
# {'name': 'door|4|5', 'position': {'x': 5.459979057312012, 'y': -0.0005959272384643555, 'z': 12.668745040893555}, 'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}, 'visible': False, 'isInteractable': False, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': True, 'isOpen': True, 'openness': 1.0, 'pickupable': False, 'isPickedUp': False, 'moveable': False, 'mass': 0.0, 'salientMaterials': None, 'receptacleObjectIds': None, 'distance': 3.458458185195923, 'objectType': 'Doorway', 'objectId': 'door|4|5', 'assetId': 'Doorway_9', 'parentReceptacles': ['Floor'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': 
# ...

# %%
spp.rnc.navigate_to_pose(({'x': 4.75, 'y': 0.9009997844696045, 'z': 12.0}, {'x': 60.0, 'y': 45.0, 'z': 0.0}))
# Out:
# navigating to:  ({'x': 4.75, 'y': 0.9009997844696045, 'z': 12.0}, {'x': 60.0, 'y': 45.0, 'z': 0.0})

# %%
spp.rnc.controller.stop()
